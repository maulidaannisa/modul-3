# %% [markdown]
# # Luaran Pembelajaran
#
# - Nilai Boolean
# - Instruksi if-elif-else
# - Perulangan dengan while dan for
# - flow control
# - operasi logik dan bitwise
# - lists and arrays.

# %% [markdown]
# # Statement Kondisi atau Percabangan
#
# Dalam pembuatan program, seringkali kita memiliki kondisi, jika..maka, contohnya: jika nilai hasil ujian > 90, maka calon peserta digital talent berhak mengikuti program beasiswa. Kondisi seperti ini dapat digambarkan dengan Flowchart seperti dibawah ini:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Operator perbandingan
#
# - Equality operator:
#     - Equality: the equal to operator `==`
#     - Inequality: the not equal to operator `!=`
# - Comparison operators:
#     - greater than `>`
#     - greater than or equal to `>=`
#     - less than or equal to `<=`

# %%
2 == 2
# Out:
# True

# %%
2 == 2.
# Out:
# True

# %%
1 == 2
# Out:
# False

# %%
var = 0 # assigning 0 to var
print(var == 0)

var = 1 # assigning 1 to var
print(var == 0)
# Out:
# True
# False

# %%
var = 0 # assigning 0 to var
print(var != 0)

var = 1 # assigning 1 to var
print(var != 0)
